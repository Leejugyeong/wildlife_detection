# %% [markdown]
# <a href="https://colab.research.google.com/github/Leejugyeong/wildlife_detection/blob/main/wildlife_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -L "https://universe.roboflow.com/ds/hixx30ehpP?key=T8Y4uKizfO" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: train/images/1--463-_jpg.rf.8d272b0bff38645b9b533961800bf9e7.jpg
#  extracting: train/images/1--463-_jpg.rf.b2f4ea07c3321ace4cebb91e3da86d81.jpg
#  extracting: train/images/1--464-_jpg.rf.492ffa7c621f5ecc3819f38d185d0614.jpg
#  extracting: train/images/1--464-_jpg.rf.b47d0b55c74cc4a00bab85e5c1fdbf67.jpg
#  extracting: train/images/1--464-_jpg.rf.f8ecccb33dd76df92ad574f97baffcff.jpg
#  extracting: train/images/1--467-_jpg.rf.01f95a41241fe5c439dfada63d76d3bc.jpg
#  extracting: train/images/1--467-_jpg.rf.997b9fcc36fedb0354653bd1d51d9b08.jpg
#  extracting: train/images/1--467-_jpg.rf.9e606677eb8031038b6f829ca8395a9c.jpg
#  extracting: train/images/1--468-_jpg.rf.3a08d2165fedae4e691780117c40578d.jpg
#  extracting: train/images/1--468-_jpg.rf.a9cc9d95161cfda21efab519df8cb364.jpg
#  extracting: train/images/1--468-_jpg.rf.f5da9e8107e2c00b6597ed98940cd64e.jpg
#  extracting: train/images/1--469-_jpg.rf.0b6d5b75a79f7e1c8c3bbc718f8cb17a.jpg
# ...

# %%
import os

print("현재 디렉토리 파일 목록:", os.listdir())
# Out:
# 현재 디렉토리 파일 목록: ['.config', 'train', 'test', 'README.dataset.txt', 'valid', 'data.yaml', 'README.roboflow.txt', 'sample_data']

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17360, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 17360 (delta 36), reused 18 (delta 18), pack-reused 17308 (from 2)
# Receiving objects: 100% (17360/17360), 16.25 MiB | 16.14 MiB/s, done.
# Resolving deltas: 100% (11901/11901), done.

# %%
# %cd /content/yolov5/
# !pip install -r requirements.txt
# Out:
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 48.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 977.1/977.1 kB 28.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# %cat /content/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 1
# names: ['wildboar']
#
# roboflow:
#   workspace: project
#   project: project2-5ufmg
#   version: 2
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/project/project2-5ufmg/dataset/2

# %%
# %cd
from glob import glob

img_list = glob('/content/train/images/*.jpg')
print(len(img_list))
# Out:
# /root
# 3252

# %%
from sklearn.model_selection import train_test_split
train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=2000)
print(len(train_img_list),len(val_img_list))
# Out:
# 2601 651

# %%
with open('/content/train.txt','w') as f:
    f.write('\n'.join(train_img_list) + '\n')
with open('/content/val.txt','w') as f:
    f.write('\n'.join(val_img_list) + '\n')

# %%
import yaml
with open('/content/data.yaml','r') as f:
  data = yaml.safe_load(f)

print(data)

data['train'] = '/content/train.txt'
data['val'] = '/content/val.txt'

with open('/content/data.yaml','w') as f:
  yaml.dump(data,f)
print(data)
# Out:
# {'train': '../train/images', 'val': '../valid/images', 'test': '../test/images', 'nc': 1, 'names': ['wildboar'], 'roboflow': {'workspace': 'project', 'project': 'project2-5ufmg', 'version': 2, 'license': 'CC BY 4.0', 'url': 'https://universe.roboflow.com/project/project2-5ufmg/dataset/2'}}
# {'train': '/content/train.txt', 'val': '/content/val.txt', 'test': '../test/images', 'nc': 1, 'names': ['wildboar'], 'roboflow': {'workspace': 'project', 'project': 'project2-5ufmg', 'version': 2, 'license': 'CC BY 4.0', 'url': 'https://universe.roboflow.com/project/project2-5ufmg/dataset/2'}}

# %%
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 50 --data /content/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name wildboar_yolov5_results
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   with torch.cuda.amp.autocast(amp):
#       34/49      2.09G     0.0159   0.009016          0         63        416:  94% 153/163 [00:47<00:03,  2.62it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      2.09G    0.01587   0.009004          0         55        416:  94% 154/163 [00:48<00:03,  2.34it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       34/49      2.09G    0.01586   0.009003          0         61        416:  95% 155/163 [00:48<00:03,  2.51it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...
